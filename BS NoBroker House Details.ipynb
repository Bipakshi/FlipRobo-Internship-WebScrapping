# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url ='https://www.nobroker.in/property/sale/bangalore/Electronic%20City?type=BHK4&searchParam=W3sibGF0IjoxMi44N%20DUyMTQ1LCJsb24iOjc3LjY2MDE2OTUsInBsYWNlSWQiOiJDaElKdy1GUWQ0cHNyanNSSGZkYXpnXzhYRW8%20iLCJwbGFjZU5hbWUiOiJFbGVjdHJvbmljIENpdHkifV0=&propertyAge=0&radius=2.0'

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n          <!DOCTYPE html><html lang="en"><head>\n          <meta property="fb:pages" content="794951570520699" />\n          <link rel="canonical" href="https://www.nobroker.in" />\n          \n          \n           \n          <link rel="dns-prefetch" href="//www.googletagmanager.com">\n          <link rel="dns-prefetch" href="//www.google-analytics.com">\n          <link rel="dns-prefetch" href="//assets.nobroker.in">\n          <link rel="dns-prefetch" href="//images.nobroker.in">\n          <link rel="shortcut icon" id="favicon" href="//assets.nobroker.in/static/img/favicon.png"/>\n          <link rel="apple-touch-icon" href="https://images.nobroker.in/static/img/fav64.png">\n          <meta charset="utf-8"/><meta charset="UTF-8"/>\n          <meta name="google-play-app" content="app-id=com.nobroker.app&referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb">\n    \t    <meta name="apple-itunes-app" content="app-id=1200507100, app-argument=nobrokerapp://">\n          <meta 
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.title.text
# Out:
# '4 BHK  Houses, Apartments for Sale in Electronic City, Bangalore | 4 BHK Flats in  Electronic City   - NoBroker'

# %%
title = []

for i in soup.find_all('h2',class_='heading-6 font-semi-bold nb__25Cl7'):
    title.append(i.text)

#title

# %%
loc =[]

for i in soup.find_all('div',class_='nb__1EwQz'):
    loc.append(i.text)
    
#loc

# %%
x =[]

for i in soup.find_all('div', class_='font-semi-bold heading-6'):
    x.append(i.text)
#x

# %%
list = [['1,800 sqft','₹77,374/Month','₹1.35 Crores'],
 ['2,000 sqft','₹39,546/Month','₹69 Lacs'],
 ['1,120 sqft','₹28,657/Month','₹50 Lacs'],
 ['2,000 sqft','₹45,851/Month','₹80 Lacs'],
 ['1,879 sqft','₹91,703/Month','₹1.6 Crores'],
 ['2,600 sqft','₹85,971/Month','₹1.5 Crores'],
 ['2,000 sqft','₹39,546/Month','₹69 Lacs'],
 ['3,000 sqft','₹71,643/Month','₹125 Crores'],
 ['3,000 sqft','₹1.43 Lacs/Month','₹2.5 Crores'],
 ['1,200 sqft','₹42,985/Month','₹75 Lacs'],
 ['2,650 sqft','₹68,777/Month','₹1.2 Crores'],
 ['3,100 sqft','₹85,971/Month','₹1.5 Crores'],
 ['1,100 sqft','₹40,120/Month','₹70 Lacs'],
 ['2,350 sqft','₹71,643/Month','₹1.25 Crores'],
 ['3,000 sqft','₹85,971/Month','₹1.5 Crores'],
 ['1,500 sqft','₹57,314/Month','₹1 Crore']]

df=pd.DataFrame(list,columns=['Area','EMI','Price'])
df
# Out:
#           Area               EMI         Price
# 0   1,800 sqft     ₹77,374/Month  ₹1.35 Crores
# 1   2,000 sqft     ₹39,546/Month      ₹69 Lacs
# 2   1,120 sqft     ₹28,657/Month      ₹50 Lacs
# 3   2,000 sqft     ₹45,851/Month      ₹80 Lacs
# 4   1,879 sqft     ₹91,703/Month   ₹1.6 Crores
# 5   2,600 sqft     ₹85,971/Month   ₹1.5 Crores
# 6   2,000 sqft     ₹39,546/Month      ₹69 Lacs
# 7   3,000 sqft     ₹71,643/Month   ₹125 Crores
# 8   3,000 sqft  ₹1.43 Lacs/Month   ₹2.5 Crores
# 9   1,200 sqft     ₹42,985/Month      ₹75 Lacs
# 10  2,650 sqft     ₹68,777/Month   ₹1.2 Crores
# 11  3,100 sqft     ₹85,971/Month   ₹1.5 Crores
# 12  1,100 sqft     ₹40,120/Month      ₹70 Lacs
# 13  2,350 sqft     ₹71,643/Month  ₹1.25 Crores
# 14  3,000 sqft     ₹85,971/Month   ₹1.5 Crores
# 15  1,500 sqft     ₹57,314/Month      ₹1 Crore

# %%
df1=pd.DataFrame(title,columns=['Title'])

# %%
#df1

# %%
df2=pd.DataFrame(loc,columns=['Location'])

# %%
#df2

# %%
df3=df1.join(df2)

# %%
df3
# Out:
#                                                 Title  \
# 0   4 BHK In Independent House  For Sale  In Hebba...
# 1   4 BHK In Independent House  For Sale  In Elect...
# 2           4 BHK Flat  For Sale  In Electronic City
# 3   4 BHK Apartment  For Sale  In Nisarga Residenc...
# 4   4 BHK Flat  For Sale  In Sobha Silicon Oasis  ...
# 5   4 BHK For Sale  In Daadys Garden In Electronic...
# 6         4 BHK Flat  For Sale  In , Electronic City
# 7   4 BHK Flat  For Sale  In Hosa Road, Parappana ...
# 8   4 BHK In Independent House  For Sale  In Elect...
# 9   4 BHK In Independent House  For Sale  In Elect...
# 10  4 BHK Apartment  For Sale  In Gopalan Gardenia...
# 11       4 BHK For Sale  In Gpr Royale In Gpr Royale
# 12  4 BHK In Independent House  For Sale  In Sarja...
# 13  4 BHK Flat  For Sale  In Heena Enclave In Elec...
# 14  4 BHK For Sale  In Deccan Palms Park In Electr...
# 15  4 BHK In Independent House  For Sale  In Elect...
#
# ...

# %%
df3.join(df)
# Out:
#                                                 Title  \
# 0   4 BHK In Independent House  For Sale  In Hebba...
# 1   4 BHK In Independent House  For Sale  In Elect...
# 2           4 BHK Flat  For Sale  In Electronic City
# 3   4 BHK Apartment  For Sale  In Nisarga Residenc...
# 4   4 BHK Flat  For Sale  In Sobha Silicon Oasis  ...
# 5   4 BHK For Sale  In Daadys Garden In Electronic...
# 6         4 BHK Flat  For Sale  In , Electronic City
# 7   4 BHK Flat  For Sale  In Hosa Road, Parappana ...
# 8   4 BHK In Independent House  For Sale  In Elect...
# 9   4 BHK In Independent House  For Sale  In Elect...
# 10  4 BHK Apartment  For Sale  In Gopalan Gardenia...
# 11       4 BHK For Sale  In Gpr Royale In Gpr Royale
# 12  4 BHK In Independent House  For Sale  In Sarja...
# 13  4 BHK Flat  For Sale  In Heena Enclave In Elec...
# 14  4 BHK For Sale  In Deccan Palms Park In Electr...
# 15  4 BHK In Independent House  For Sale  In Elect...
#
# ...
